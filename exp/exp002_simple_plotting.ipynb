# %% [markdown]
# We want to plot the parsed email data to get an understanding of the data.

# %%
# %run ../src/parse_mails.py

df = parse_maildir("../data/maildir")

# %%
df.head()
# Out:
#                                            name  \
# ../data/maildir/mckay-b/_sent_mail/44.  mckay-b
# ../data/maildir/mckay-b/_sent_mail/11.  mckay-b
# ../data/maildir/mckay-b/_sent_mail/38.  mckay-b
# ../data/maildir/mckay-b/_sent_mail/13.  mckay-b
# ../data/maildir/mckay-b/_sent_mail/33.  mckay-b
#
#                                                                                  date  \
# ../data/maildir/mckay-b/_sent_mail/44.   Date: Mon, 7 May 2001 04:44:00 -0700 (PDT)\n
# ../data/maildir/mckay-b/_sent_mail/11.   Date: Tue, 3 Oct 2000 01:18:00 -0700 (PDT)\n
# ../data/maildir/mckay-b/_sent_mail/38.   Date: Tue, 8 May 2001 04:11:00 -0700 (PDT)\n
# ../data/maildir/mckay-b/_sent_mail/13.  Date: Wed, 27 Sep 2000 04:51:00 -0700 (PDT)\n
# ../data/maildir/mckay-b/_sent_mail/33.   Date: Wed, 9 May 2001 09:14:00 -0700 (PDT)\n
#
#                                                       parsed_date      time  \
# ../data/maildir/mckay-b/_sent_mail/44.  2001-05-07 04:44:00-07:00  04:44:00
# ../data/maildir/mckay-b/_sent_mail/11.  2000-10-03 01:18:00-07:00  01:18:00
# ../data/maildir/mckay-b/_sent_mail/38.  2001-05-08 04:11:00-07:00  04:11:00
# ../data/maildir/mckay-b/_sent_mail/13.  2000-09-27 04:51:00-07:00  04:51:00
# ../data/maildir/mckay-b/_sent_mail/33.  2001-05-09 09:14:00-07:00  09:14:00
#
#                                                day   tz
# ../data/maildir/mckay-b/_sent_mail/44.  2001-05-07  PDT
# ../data/maildir/mckay-b/_sent_mail/11.  2000-10-03  PDT
# ../data/maildir/mckay-b/_sent_mail/38.  2001-05-08  PDT
# ../data/maildir/mckay-b/_sent_mail/13.  2000-09-27  PDT
# ../data/maildir/mckay-b/_sent_mail/33.  2001-05-09  PDT

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

df["seconds_since_midnight"] = df["time"].apply(lambda x: x.hour * 60 * 60 + x.minute * 60 + x.second)

def seconds_in_time(x, pos):
    hours = x // 3600
    minutes = (x - (hours * 3600)) // 60
    return '%d:%d' % (hours, minutes)

formatter = FuncFormatter(seconds_in_time)

fig, axs = plt.subplots(1, 1, figsize=(40, 17))
axs.scatter(df["seconds_since_midnight"], df["name"], s=1)
axs.xaxis.set_major_formatter(formatter)

plt.show()

# %%
# Out:
# '1:0'
